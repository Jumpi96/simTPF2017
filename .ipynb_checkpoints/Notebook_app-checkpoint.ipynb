# %% [markdown]
# # Trabajo Práctico Final - Simulación #

# %%
from Simulacion import *
from os import environ
from IPython.display import HTML
from IPython.display import Markdown, display
from IPython.display import display
import pickle
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Modelo de simulación ##
# El modelo consta de los siguientes objetos:
# * Grúa {Viajando a P1, Viajando a P2, Esperando en P1, Esperando en P2}
# * Auto
#
# Además, tenemos los siguientes eventos:
# * Llegada auto P1: con distribución exponencial negativa de media 1'.
# * Llegada auto P2: con distribución exponencial negativa de media 1,875'.
# * Arribo a P1: llegada y descarga de grúa en P1.
# * Arribo a P2: llegada y descarga de grúa en P2.
# * Abandono: un auto abandona la fila después de pasados 10 minutos de su llegada.

# %% [markdown]
# ## Parámetros e interfaz ##

# %%
with open('param.pickle', 'rb') as handle:
    param = pickle.load(handle)

p_precio_auto_a = float(param['p_precio_auto_a'])
p_precio_auto_b = float(param['p_precio_auto_b'])
p_precio_abandono_a = float(param['p_precio_abandono_a'])
p_precio_abandono_b = float(param['p_precio_abandono_b'])
p_costo_grua_a = float(param['p_costo_grua_a'])
p_costo_grua_b = float(param['p_costo_grua_b'])
p_tiempo_grua_a = float(param['p_tiempo_grua_a'])
p_tiempo_grua_b = float(param['p_tiempo_grua_b'])
p_capac_grua_a = float(param['p_capac_grua_a'])
p_capac_grua_b = float(param['p_capac_grua_b'])
p_serv_min_a = float(param['p_serv_min_a'])
p_serv_min_b = float(param['p_serv_min_b'])
p_tiempo = float(param['p_tiempo'])
p_mostrar_desde = float(param['p_mostrar_desde'])
p_iteraciones = float(param['p_iteraciones'])

# %%
def View(df,num):
    css = """<style>
    table { border-collapse: collapse; border: 3px solid #eee; }
    table tr th:first-child { background-color: #eeeeee; color: #333; font-weight: bold }
    table thead th { background-color: #eee; color: #000; }
    tr, th, td { border: 1px solid #ccc; border-width: 1px 0 0 1px; border-collapse: collapse;
    padding: 3px; font-family: monospace; font-size: 10px }</style>
    """
    s  = '<script type="text/Javascript">'
    s += 'var win = window.open("", "' + num + '", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));'
    s += 'win.document.body.innerHTML = \'' + (df.to_html() + css).replace("\n",'\\') + '\';'
    s += 'win.document.title = "Simulación - Opción '+num+'";'
    s += '</script>'
    return(HTML(s+css))

# %% [markdown]
# ## Simulación - Opción A##

# %% [markdown]
# En el ejercicio original, implica esperar a completar la grúa antes de empezar el traslado.

# %%
s1 = Simulacion(p_precio_auto_a,p_precio_abandono_a,p_costo_grua_a,p_tiempo,p_mostrar_desde,p_iteraciones,
     p_tiempo_grua_a,p_capac_grua_a,p_serv_min_a)
tabla_uno = s1.simular()

# %%
View(tabla_uno,"A")
# Out:
# <script type="text/Javascript">var win = window.open("", "A", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>Estado</th>\      <th>Reloj</th>\      <th>RND P1</th>\      <th>Tiempo lleg. P1</th>\      <th>Prox. lleg. P1</th>\      <th>RND P2</th>\      <th>Tiempo lleg. P2</th>\      <th>Prox. lleg. P2</th>\      <th>i de llegada</th>\      <th>Destino traslado</th>\      <th>Fin traslado</th>\      <th>Estado grua</th>\      <th>Cola P1</th>\      <th>Cola P2</th>\      <th>Acum. Ganancias</th>\      <th>Cont. Perdidos</th>\      <th>Cont. Atendidos</th>\      <th>Acum. Permanencia</th>\      <th>Auto 1</th>\      <th>Estado 1</th>\      <th>Llegada 1</th>\      <th>Fin espera 1</th>\      <th>Fin traslado 1</th>\      <th>Auto 2</th>\      <th>Estado 2</th>\      <th>Llegada 2</th>\      <th>Fin espera 2</th>\      <th>Fin traslado 2</th>\      <th>Auto 3</th>\      <th>Estado 3</th>\      <th>Llegada 3</th>\      <th>Fin espera 3</th>\      <th>Fin traslado 3</th>\      <th>Auto 4</th>\      <th>Estado 4</th>\      <th>Llegada 4</th>\      <th>Fin espera 4</th>\      <th>Fin traslado 4</th>\      <th>Auto 5</th>\      <th>Estado 5</th>\      <th>Llegada 5</th>\      <th>Fin espera 5</th>\      <th>Fin traslado 5</th>\      <th>Auto 6</th>\      <th>Estado 6</th>\      <th>Llegada 6</th>\      <th>Fin espera 6</th>\      <th>Fin traslado 6</th>\      <th>Auto 7</th>\      <th>Estado 7</th>\      <th>Llegada 7</th>\      <th>Fin espera 7</th>\      <th>Fin traslado 7</th>\      <th>Auto 8</th>\      <th>Estado 8</th>\      <th>Llegada 8</th>\      <th>Fin espera 8</th>\      <th>Fin traslado 8</th>\      <th>Auto 9</th>\      <th>Estado 9</th>\      <th>Llegada 9</th>\      <th>Fin espera 9</th>\      <th>Fin traslado 9</th>\      <th>Auto 10</th>\      <th>Estado 10</th>\      <th>Llegada 10</th>\      <th>Fin espera 10</th>\      <th>Fin traslado 10</th>\      <th>Auto 11</th>\      <th>Estado 11</th>\      <th>Llegada 11</th>\      <th>Fin espera 11</th>\      <th>Fin traslado 11</th>\      <th>Auto 12</th>\      <th>Estado 12</th>\      <th>Llegada 12</th>\      <th>Fin espera 12</th>\      <th>Fin traslado 12</th>\      <th>Auto 13</th>\      <th>Estado 13</th>\      <th>Llegada 13</th>\      <th>Fin espera 13</th>\      <th>Fin traslado 13</th>\      <th>Auto 14</th>\      <th>Estado 14</th>\      <th>Llegada 14</th>\      <th>Fin espera 14</th>\      <th>Fin traslado 14</th>\      <th>Auto 15</th>\      <th>Estado 15</th>\      <th>Llegada 15</th>\      <th>Fin espera 15</th>\      <th>Fin traslado 15</th>\      <th>Auto 16</th>\      <th>Estado 16</th>\      <th>Llegada 16</th>\      <th>Fin espera 16</th>\      <th>Fin traslado 16</th>\      <th>Auto 17</th>\      <th>Estado 17</th>\      <th>Llegada 17</th>\      <th>Fin espera 17</th>\      <th>Fin traslado 17</th>\      <th>Auto 18</th>\      <th>Estado 18</th>\      <th>Llegada 18</th>\      <th>Fin espera 18</th>\      <th>Fin traslado 18</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>1</th>\      <td>Inicio del dia</td>\      <td>0</td>\      <td>0.064606</td>\      <td>0.0667875</td>\      <td>0.0667875</td>\      <td>0.958497</td>\      <td>5.96622</td>\      <td>5.96622</td>\      <td>-</td>\      <td>-</td>\      <td>-</td>\      <td>Esperando en P1</td>\      <td>0</td>\      <td>0</td>\      <td>0</td>\      <td>0</td>\      <td>0</td>\      <td>0</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</td>\      <td>NaN</t ...

# %% [markdown]
# ## Simulación - Opción B##

# %% [markdown]
# En el ejercicio original, se espera sólo a tener cómo mínimo tres autos antes de que la grúa empiece el traslado.

# %%
s2 = Simulacion(p_precio_auto_b,p_precio_abandono_b,p_costo_grua_b,p_tiempo,p_mostrar_desde,p_iteraciones,
     p_tiempo_grua_b,p_capac_grua_b,p_serv_min_b)
tabla_dos = s2.simular()

# %%
View(tabla_dos,"B")
# Out:
# <script type="text/Javascript">var win = window.open("", "B", "toolbar=no, location=no, directories=no, status=no, menubar=no, scrollbars=yes, resizable=yes, width=780, height=200, top="+(screen.height-400)+", left="+(screen.width-840));win.document.body.innerHTML = '<table border="1" class="dataframe">\  <thead>\    <tr style="text-align: right;">\      <th></th>\      <th>Estado</th>\      <th>Reloj</th>\      <th>RND P1</th>\      <th>Tiempo lleg. P1</th>\      <th>Prox. lleg. P1</th>\      <th>RND P2</th>\      <th>Tiempo lleg. P2</th>\      <th>Prox. lleg. P2</th>\      <th>i de llegada</th>\      <th>Destino traslado</th>\      <th>Fin traslado</th>\      <th>Estado grua</th>\      <th>Cola P1</th>\      <th>Cola P2</th>\      <th>Acum. Ganancias</th>\      <th>Cont. Perdidos</th>\      <th>Cont. Atendidos</th>\      <th>Acum. Permanencia</th>\      <th>Auto 1</th>\      <th>Estado 1</th>\      <th>Llegada 1</th>\      <th>Fin espera 1</th>\      <th>Fin traslado 1</th>\      <th>Auto 2</th>\      <th>Estado 2</th>\      <th>Llegada 2</th>\      <th>Fin espera 2</th>\      <th>Fin traslado 2</th>\      <th>Auto 3</th>\      <th>Estado 3</th>\      <th>Llegada 3</th>\      <th>Fin espera 3</th>\      <th>Fin traslado 3</th>\      <th>Auto 4</th>\      <th>Estado 4</th>\      <th>Llegada 4</th>\      <th>Fin espera 4</th>\      <th>Fin traslado 4</th>\      <th>Auto 5</th>\      <th>Estado 5</th>\      <th>Llegada 5</th>\      <th>Fin espera 5</th>\      <th>Fin traslado 5</th>\      <th>Auto 6</th>\      <th>Estado 6</th>\      <th>Llegada 6</th>\      <th>Fin espera 6</th>\      <th>Fin traslado 6</th>\      <th>Auto 7</th>\      <th>Estado 7</th>\      <th>Llegada 7</th>\      <th>Fin espera 7</th>\      <th>Fin traslado 7</th>\      <th>Auto 8</th>\      <th>Estado 8</th>\      <th>Llegada 8</th>\      <th>Fin espera 8</th>\      <th>Fin traslado 8</th>\      <th>Auto 9</th>\      <th>Estado 9</th>\      <th>Llegada 9</th>\      <th>Fin espera 9</th>\      <th>Fin traslado 9</th>\      <th>Auto 10</th>\      <th>Estado 10</th>\      <th>Llegada 10</th>\      <th>Fin espera 10</th>\      <th>Fin traslado 10</th>\      <th>Auto 11</th>\      <th>Estado 11</th>\      <th>Llegada 11</th>\      <th>Fin espera 11</th>\      <th>Fin traslado 11</th>\      <th>Auto 12</th>\      <th>Estado 12</th>\      <th>Llegada 12</th>\      <th>Fin espera 12</th>\      <th>Fin traslado 12</th>\      <th>Auto 13</th>\      <th>Estado 13</th>\      <th>Llegada 13</th>\      <th>Fin espera 13</th>\      <th>Fin traslado 13</th>\      <th>Auto 14</th>\      <th>Estado 14</th>\      <th>Llegada 14</th>\      <th>Fin espera 14</th>\      <th>Fin traslado 14</th>\      <th>Auto 15</th>\      <th>Estado 15</th>\      <th>Llegada 15</th>\      <th>Fin espera 15</th>\      <th>Fin traslado 15</th>\      <th>Auto 16</th>\      <th>Estado 16</th>\      <th>Llegada 16</th>\      <th>Fin espera 16</th>\      <th>Fin traslado 16</th>\      <th>Auto 17</th>\      <th>Estado 17</th>\      <th>Llegada 17</th>\      <th>Fin espera 17</th>\      <th>Fin traslado 17</th>\      <th>Auto 18</th>\      <th>Estado 18</th>\      <th>Llegada 18</th>\      <th>Fin espera 18</th>\      <th>Fin traslado 18</th>\      <th>Auto 19</th>\      <th>Estado 19</th>\      <th>Llegada 19</th>\      <th>Fin espera 19</th>\      <th>Fin traslado 19</th>\      <th>Auto 20</th>\      <th>Estado 20</th>\      <th>Llegada 20</th>\      <th>Fin espera 20</th>\      <th>Fin traslado 20</th>\      <th>Auto 21</th>\      <th>Estado 21</th>\      <th>Llegada 21</th>\      <th>Fin espera 21</th>\      <th>Fin traslado 21</th>\      <th>Auto 22</th>\      <th>Estado 22</th>\      <th>Llegada 22</th>\      <th>Fin espera 22</th>\      <th>Fin traslado 22</th>\    </tr>\  </thead>\  <tbody>\    <tr>\      <th>1</th>\      <td>Inicio del dia</td>\      <td>0</td>\      <td>0.783218</td>\      <td>1.52886</td>\      <td>1.52886</td>\      <td>0.482533</td>\      <td>1.23527</td>\      <td>1.23 ...

# %% [markdown]
# ## Análisis y estadísticas ##

# %%
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

def printmd(string):
    display(Markdown(string))

# %% [markdown]
# ### Ganancias acumuladas

# %%
A_val=s1.acum_ganancias
B_val=s2.acum_ganancias
ind = np.arange(1)
width = 0.05

fig, ax = plt.subplots()
rects1 = ax.bar(ind, A_val, width, color='r')
rects2 = ax.bar(ind + width, B_val, width, color='y')

ax.set_ylabel('Ganancias')
ax.set_title('Ganancias acumuladas')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('G'))

ax.legend((rects1[0], rects2[0]), ('Opción A', 'Opción B'))

autolabel(rects1)
autolabel(rects2)

plt.show()

# %% [markdown]
# ### Tiempo de permanencia promedio

# %% [markdown]
# Se tiene en cuenta desde la llegada hasta el fin de la atención sólo a vehículos atendidos.

# %%
A_val = ((s1.acum_permanencia/s1.cont_atendidos))
B_val = ((s2.acum_permanencia/s2.cont_atendidos))
ind = np.arange(1)
width = 0.05

fig, ax = plt.subplots()
rects1 = ax.bar(ind, A_val, width, color='b')
rects2 = ax.bar(ind + width, B_val, width, color='g')

ax.set_ylabel('Tiempo')
ax.set_title('Promedio de permanencia')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('P'))

ax.legend((rects1[0], rects2[0]), ('Opción A', 'Opción B'))

printmd("**Promedio Opción A: **" + '{0:.6g}'.format(A_val) + " seg.")
printmd("**Promedio Opción B: **" + '{0:.6g}'.format(B_val) + " seg.")
plt.show()
# Out:
# **Promedio Opción A: **12.1614 seg.
# **Promedio Opción B: **12.2219 seg.

# %% [markdown]
# ### Cantidad de abandonos ###
# Podemos analizar la cantidad de abandonos durante el período de la simulación mostrada en el estado actual y con la mejora propuesta.

# %%
if p_iteraciones != '0':
    data_a=pd.DataFrame()
    data_a[["Reloj","Cont. Perdidos"]] = tabla_uno[["Reloj","Cont. Perdidos"]].copy()
    max_hora_a = data_a.loc[len(data_a)][0]

    data_b=pd.DataFrame()
    data_b[["Reloj","Cont. Perdidos"]] = tabla_dos[["Reloj","Cont. Perdidos"]].copy()
    max_hora_b = data_b.loc[len(data_b)][0]

    max_len = min(len(data_a),len(data_b))
    data_a = data_a[:][0:max_len]
    data_b = data_b[:][0:max_len]

    max_hora= min(max_hora_a,max_hora_b)

    X = np.linspace(float(p_mostrar_desde), max_hora,len(data_a),endpoint=True)
    plt.plot(X,data_a["Cont. Perdidos"],label='A')
    plt.plot(X,data_b["Cont. Perdidos"],label='B')
    plt.xlabel('Tiempo (min.)')
    plt.ylabel('Cantidad')
    plt.legend(loc='upper left')
    plt.title('Cantidad de abandonos')
    plt.show()

# %% [markdown]
# ### Proporción de clientes que abandonan ###
# Podemos analizar la cantidad de abandonos respecto con la cantidad de clientes bancarios que si se atienden, con las dos soluciones.

# %%
Z1 = [s1.cont_abandonos,s1.cont_atendidos]
Z2 = [s2.cont_abandonos,s2.cont_atendidos]
plt.pie(Z1,labels=("Abandonos","Atendidos"),autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.legend(loc='upper left')
plt.title('Opción A')
plt.show()

plt.pie(Z2,labels=("Abandonos","Atendidos"), autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.legend(loc='upper left')
plt.title('Opción B')
plt.show()

# %% [markdown]
# ## Conclusiones del ejercicio original ##
# * Se observa claramente que las ganancias del sistema dependen de la cantidad de abandonos que se hayan producido, que no bajan del 50% de los arribados, con cualquiera de las opciones.
# * Se logra así entonces reducir el porcentaje de abandonos respecto a autos arribados al cruce con la opción B, con una diferencia significativa (5-10 %).
# * El sistema es deficitario de cualquiera de las formas, teniendo que ser revisado si se quiere revertir esto el costo de traslado del auto, la capacidad de cada traslado o el tiempo del mismo.
#     *
